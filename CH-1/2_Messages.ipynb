# %% [markdown]
# # **MESSAGES**

# %%
from  langchain_openai import ChatOpenAI
import os 
from dotenv import load_dotenv

# This function will load all the variables from the .env file and will 
# make them available in the os.environ dictionary (env variables)
load_dotenv() 

if os.environ.get("OPENAI_API_KEY"):
    print("Bro API KEY Variable exists")
else:
    raise ValueError("OPENAI_API_KEY not found")
# Out:
# Bro API KEY Variable exists

# %%
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
from  langchain_openai import ChatOpenAI

llm_openai = ChatOpenAI(model="gpt-5-mini",temperature=0)
my_messages = [
    SystemMessage(content="You are a professional serious assistant who always answers in a fun way"),
    HumanMessage(content="Bro, where is bengaluru")
]

llm_openai.invoke(my_messages).content
# Out:
# c:\Users\abhshukl10\OneDrive - Publicis Groupe\Desktop\multiagent\.venv\Lib\site-packages\langchain_core\_api\deprecation.py:26: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1
# 'Bro — Bengaluru (aka Bangalore) is in southern India. It\'s the capital of Karnataka on the Deccan Plateau.\n\nQuick facts:\n- Coordinates: ~12.9716° N, 77.5946° E\n- Time zone: IST (UTC+5:30)\n- Elevation: ~900 m (so it\'s kinda nice and breezy)\n- Nickname: "Silicon Valley of India"\n- Major airport: Kempegowda International Airport (BLR)\n- Rough distances: ~350 km west of Chennai, ~980 km east of Mumbai, ~1,740 km south of New Delhi\n- Metro pop: ~10–12 million (big city energy)\n\nWanna drop a pin or get directions? I can open a map link for you. 🚀'

# %% [markdown]
# # **Prompts**
#
# Prompts are the messages that are sent to the LLM. Prompts are more user-friendly than messages.

# %%
from langchain_core.prompts import PromptTemplate


user_input = input("Enter a topic for fun fact : ")

dynamic_prompt = PromptTemplate.from_template("Write a fun fact about {topic}")

ready_prompt = dynamic_prompt.invoke({"topic" : user_input})

llm_openai.invoke(ready_prompt).content
# Out:
# StringPromptValue(text='Write a fun fact about What is the capital of France')

# %%
from langchain_core.prompts import ChatPromptTemplate 

prompt_template = ChatPromptTemplate.from_messages([
    ("system","You are a {tone} assistant"),
    ("user","Write a fun fact about {topic}.")
])

user_input = input("Enter a topic: ")
user_tone = input("Enter a tone: ")

ready_prompt = prompt_template.invoke({"topic":user_input,"tone":user_tone})

llm_openai.invoke(ready_prompt.messages)
# Out:
# AIMessage(content='Fun fact: Honey never spoils — archaeologists have found edible honey in ancient Egyptian tombs thousands of years old. So while your leftovers lose their will to live after a week, honey is basically the immortal candy of the pantry.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 376, 'prompt_tokens': 22, 'total_tokens': 398, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 320, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CvmF2gDBw3fcgldcCIug8nwrZoXWB', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b9e3a-2dcb-71e2-8915-4e74d180a516-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 22, 'output_tokens': 376, 'total_tokens': 398, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 320}})
