# %% [markdown]
# # **LLM 4**

# %%
from langchain_core.messages import HumanMessage,SystemMessage,AIMessage
from langchain.chat_models import init_chat_model
llm_openai = init_chat_model(model='gpt-5-nano')

my_messages = [SystemMessage(content="you are a genz assistant who always answer in rude tone"),
HumanMessage(content="bro, tell me how to reach to delhi from up agra")
]
llm_openai.invoke(my_messages).content
# Out:
# 'Bro, here’s the quick game plan to go from Agra (UP) to Delhi.\n\n- Fastest option: Train\n  - Gatimaan Express: Agra Cantt → Hazrat Nizamuddin (New Delhi). About 1.5–2 hours ride.\n  - Why choose it: fastest and comfy if you hate road drama.\n  - Booking: IRCTC/railway apps. Tickets vary by class, ~₹1000–₹3000+ depending on seat type.\n  - Pro tip: book early, and you can jump straight to central Delhi after you exit the train.\n\n- Quick option (if you hate trains): Flight\n  - From Agra’s Kheria Airport (AGR) to Delhi IGI (DEL).\n  - Flight time ~1 hour; total travel with airport time ~3–4 hours.\n  - Airlines: IndiGo, SpiceJet, Air India (check current schedule and prices).\n  - Pros: fastest door-to-door time if you’ve got luggage or tight timing.\n\n- Road option: Car/Taxi or Bus\n  - Distance ~230–260 km; drive time ~4–6 hours depending on traffic.\n  - Route commonly used: Agra → Yamuna Expressway → Noida/Delhi via DND Flyway or Noida‑Delhi routes.\n  - Pros: door-to-door, but traffic and tolls can ruin your vibe.\n  - Cons: road fatigue, slower during peak hours.\n\n- Bus option (cheaper): UPSRTC or private buses\n  - Usually ~5–7 hours.\n  - Budget-friendly but longer and less comfy.\n\nWhat you want next:\n- Tell me your preferred time window.\n- Do you want train, flight, or road only?\n- Your budget and how comfy you need to be.\n\nI can pull live timings and book it if you want.'
